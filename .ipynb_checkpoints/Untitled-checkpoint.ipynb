# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\reetb\\Desktop\\AgAthon'

# %%
import pandas as pd

# %%
df = pd.read_csv('points_data3.csv')

# %%
len(df['Irrigtn'].unique())
# Out:
# 19

# %%
apple = df.loc[df['CropTyp'] == 'apple']

# %%
apple = apple.dropna(subset=['EVI', 'NVDI', 'Albedo', 'GNDVI', 'MSR','OSAVI', 'PVR', 'VARIG', 'SIPI', 'GARI', 'mNVDI', 'EPIChlb', 'NDII'])

# %%
apple = apple.drop(['ID', 'CropTyp', 'Acres', 'Irrigtn', 'IntlSrD', 'LstSrvD', 'DataSrc',
       'Notes', 'TRS', 'county', 'RtCrpTy', 'ExctAcr', 'Shp_Lng', 'Shap_Ar',
       'CropGrp', 'date', 'year', 'NVDI', 'GNDVI', 'MSR',
       'OSAVI', 'VARIG', 'SIPI', 'GARI', 'mNVDI', 'EPIChlb'])
# Out:
# Index(['ID', 'CropTyp', 'Acres', 'Irrigtn', 'IntlSrD', 'LstSrvD', 'DataSrc',
#        'Notes', 'TRS', 'county', 'RtCrpTy', 'ExctAcr', 'Shp_Lng', 'Shap_Ar',
#        'CropGrp', 'date', 'year', 'EVI', 'NVDI', 'Albedo', 'GNDVI', 'MSR',
#        'OSAVI', 'PVR', 'VARIG', 'SIPI', 'GARI', 'mNVDI', 'EPIChlb', 'NDII'],
#       dtype='object')

# %%
df = df.dropna(subset=['EVI', 'NVDI', 'Albedo', 'GNDVI', 'MSR','OSAVI', 'PVR', 'VARIG', 'SIPI', 'GARI', 'mNVDI', 'EPIChlb', 'NDII'])

# %%
df = df.drop(['ID', 'IntlSrD', 'LstSrvD', 'DataSrc', 'Notes', 'TRS', 'county', 'RtCrpTy', 'ExctAcr', 'Shp_Lng', 'Shap_Ar', 'date', 'year'], axis=1)

# %%
df
# Out:
#                         CropTyp  Acres               Irrigtn       CropGrp  \
# 0                         apple      4       micro-sprinkler       Orchard
# 1                     bean, dry     37          center pivot     Vegetable
# 3                     bean, dry     84          center pivot     Vegetable
# 4                         apple     24       micro-sprinkler       Orchard
# 5                         wheat     60                  rill  Cereal Grain
# ...                         ...    ...                   ...           ...
# 2245                alfalfa hay     20            wheel line    Hay/Silage
# 2246                alfalfa hay     92          center pivot    Hay/Silage
# 2247  nursery, orchard/vineyard     33  drip/micro-sprinkler       Nursery
# 2248                      apple      1        drip/sprinkler       Orchard
# 2249                       mint     26          center pivot          Herb
#
#            EVI      NVDI    Albedo     GNDVI       MSR     OSAVI       PVR  \
# 0     0.427817  0.794949  0.132105  0.754783  2.093314  0.546581  0.116400
# 1     0.250359  0.350633  0.132260  0.434539  0.447128  0.616196 -0.098923
# 3     0.293365  0.374090  0.158922  0.494862  0.482988  0.636737 -0.148304
# 4     0.556109  0.829215  0.174470  0.759875  2.345889  0.577111  0.197388
# 5     0.366269  0.652205  0.129180  0.660435  1.223464  0.568183 -0.007552
# ...        ...       ...       ...       ...       ...       ...       ...
# 2245  0.666071  0.916694  0.207213  0.833653  3.866195  0.621325  0.358022
# 2246  0.728124  0.923599  0.231826  0.851732  4.045819  0.678916  0.339187
# 2247  0.269170  0.370053  0.137566  0.444480  0.477110  0.614353 -0.088953
# 2248  0.429977  0.760587  0.136571  0.700573  1.711784  0.550394  0.128469
# 2248  0.634769  0.905706  0.020790  0.534814
# 2249  0.690162  0.912470  0.022618  0.486690
#
# [1877 rows x 17 columns]

# %%
df
# Out:
#       CropTyp  Acres               Irrigtn       CropGrp       EVI      NVDI  \
# 0           4      4       micro-sprinkler       Orchard  0.427817  0.794949
# 1           9     37          center pivot     Vegetable  0.250359  0.350633
# 3           9     84          center pivot     Vegetable  0.293365  0.374090
# 4           4     24       micro-sprinkler       Orchard  0.556109  0.829215
# 5          51     60                  rill  Cereal Grain  0.366269  0.652205
# ...       ...    ...                   ...           ...       ...       ...
# 2245        0     20            wheel line    Hay/Silage  0.666071  0.916694
# 2246        0     92          center pivot    Hay/Silage  0.728124  0.923599
# 2247       33     33  drip/micro-sprinkler       Nursery  0.269170  0.370053
# 2248        4      1        drip/sprinkler       Orchard  0.429977  0.760587
# 2249       31     26          center pivot          Herb  0.469394  0.802415
#
#         Albedo     GNDVI       MSR     OSAVI       PVR     VARIG      SIPI  \
# 0     0.132105  0.754783  2.093314  0.546581  0.116400  0.145814  0.891848
# 1     0.132260  0.434539  0.447128  0.616196 -0.098923 -0.137691  0.590718
# 3     0.158922  0.494862  0.482988  0.636737 -0.148304 -0.205206  0.614956
# 4     0.174470  0.759875  2.345889  0.577111  0.197388  0.277133  0.868445
# 5     0.129180  0.660435  1.223464  0.568183 -0.007552 -0.010992  0.824724
# ...        ...       ...       ...       ...       ...       ...       ...
# 2245  0.207213  0.833653  3.866195  0.621325  0.358022  0.490142  0.928778
# 2246  0.231826  0.851732  4.045819  0.678916  0.339187  0.491979  0.926199
# 2247  0.137566  0.444480  0.477110  0.614353 -0.088953 -0.126466  0.584536
# 2248  0.136571  0.700573  1.711784  0.550394  0.128469  0.181951  0.829813
# 2249  0.144192  0.762352  2.089402  0.553322  0.111841  0.156255  0.863017
#
#           GARI     mNVDI   EPIChlb      NDII
# 0     0.661317  0.877803  0.022413  0.522117
# 1     0.208436  0.501827  0.048898  0.536452
# 3     0.234926  0.499062  0.059000  0.468877
# 4     0.709110  0.941120  0.016380  0.522670
# 5     0.483125  0.745229  0.035458  0.527230
# ...        ...       ...       ...       ...
# 2245  0.818325  0.984785  0.008440  0.556332
# 2246  0.843325  0.994638  0.009059  0.545877
# 2247  0.236548  0.544801  0.047151  0.480429
# 2248  0.634769  0.905706  0.020790  0.534814
# 2249  0.690162  0.912470  0.022618  0.486690
#
# [1877 rows x 17 columns]

# %%
from sklearn.compose import make_column_transformer

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
column_trans = make_column_transformer((OneHotEncoder(), ['Irrigtn', 'CropGrp']), remainder='passthrough')

# %%
df = column_trans.fit_transform(df)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max_scaler = MinMaxScaler()

# %%
X = min_max_scaler.fit_transform(df)

# %%
X
# Out:
# array([[0.        , 0.        , 0.        , ..., 0.84019588, 0.2229831 ,
#         0.54410377],
#        [0.        , 1.        , 0.        , ..., 0.34924379, 0.5886954 ,
#         0.59042957],
#        [0.        , 1.        , 0.        , ..., 0.34563317, 0.72819526,
#         0.37204394],
#        ...,
#        [0.        , 0.        , 0.        , ..., 0.40535988, 0.56457157,
#         0.40937683],
#        [0.        , 0.        , 0.        , ..., 0.8766316 , 0.2005789 ,
#         0.58513618],
#        [0.        , 1.        , 0.        , ..., 0.88546481, 0.22581039,
#         0.42961123]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, label, test_size=0.3, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf1 = RandomForestClassifier(max_depth=2, random_state=0, n_estimators=1000)

# %%
clf1.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=2, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=1000,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
y_pred1 = clf1.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred1)
# Out:
# 0.5425531914893617

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
clf2 = GradientBoostingClassifier(random_state=0)

# %%
clf2.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='auto',
#                            random_state=0, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
y_pred2 = clf2.predict(X_test)

# %%
accuracy_score(y_test, y_pred2)
# Out:
# 0.9468085106382979

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
clf3 = KNeighborsClassifier(n_neighbors=20)

# %%
clf3.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=20, p=2,
#                      weights='uniform')

# %%
y_pred3 = clf3.predict(X_test)

# %%
accuracy_score(y_test, y_pred3)
# Out:
# 0.8297872340425532

# %%
pred = pd.DataFrame(y_pred1, columns =['Pred1'])

# %%
pred['Pred2'] = y_pred2
pred['Pred3'] = y_pred3

# %%
pred
# Out:
#      Pred1  Pred2  Pred3
# 0        0     28      0
# 1        0      0      0
# 2       21     24     38
# 3        9     22      9
# 4        4     38     38
# ..     ...    ...    ...
# 559      4      4      4
# 560      4     27     27
# 561      0      0      0
# 562     21     21     21
# 563     21     35      9
#
# [564 rows x 3 columns]

# %%
y_pred = pred.mode(axis=1)

# %%
y_pred
# Out:
#         0     1     2
# 0     0.0   NaN   NaN
# 1     0.0   NaN   NaN
# 2    21.0  24.0  38.0
# 3     9.0   NaN   NaN
# 4    38.0   NaN   NaN
# ..    ...   ...   ...
# 559   4.0   NaN   NaN
# 560  27.0   NaN   NaN
# 561   0.0   NaN   NaN
# 562  21.0   NaN   NaN
# 563   9.0  21.0  35.0
#
# [564 rows x 3 columns]

# %%
accuracy_score(y_test, y_pred[0])
# Out:
# 0.8226950354609929

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred[0]))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.81      1.00      0.89        79
#          2.0       0.00      0.00      0.00         2
#          3.0       0.00      0.00      0.00         1
#          4.0       0.72      1.00      0.83       121
#          5.0       0.00      0.00      0.00         1
#          6.0       0.00      0.00      0.00         3
#          7.0       0.00      0.00      0.00         0
#          9.0       0.55      0.94      0.69        31
#         10.0       0.00      0.00      0.00         4
#         14.0       0.00      0.00      0.00         2
#         15.0       0.00      0.00      0.00         2
#         17.0       1.00      0.64      0.78        22
#         18.0       0.00      0.00      0.00         1
#         20.0       0.00      0.00      0.00         1
#         21.0       0.93      1.00      0.97        69
#         22.0       1.00      0.38      0.55        21
#         23.0       0.00      0.00      0.00         1
#         24.0       1.00      0.63      0.77        19
#         25.0       0.00      0.00      0.00         2
#         26.0       0.00      0.00      0.00         2
#         27.0       1.00      1.00      1.00         9
#         28.0       0.00      0.00      0.00         9
#         31.0       1.00      0.83      0.91         6
#         32.0       0.00      0.00      0.00         3
#         33.0       1.00      0.50      0.67         8
#         35.0       0.00      0.00      0.00         6
#         36.0       0.00      0.00      0.00         1
#         38.0       1.00      0.92      0.96        24
#         40.0       0.00      0.00      0.00         4
#         41.0       0.00      0.00      0.00         7
#         42.0       0.90      1.00      0.95        18
#         45.0       0.00      0.00      0.00         2
#         46.0       1.00      0.67      0.80         3
#         48.0       0.00      0.00      0.00         3
#         49.0       1.00      0.93      0.96        40
#         51.0       1.00      0.97      0.99        36
#         53.0       0.00      0.00      0.00         1
#
#     accuracy                           0.82       564
#    macro avg       0.38      0.34      0.34       564
# weighted avg       0.77      0.82      0.78       564
# C:\Users\reetb\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\reetb\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
print(classification_report(y_test, y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      1.00      0.73        79
#            2       0.00      0.00      0.00         2
#            3       0.00      0.00      0.00         1
#            4       0.52      1.00      0.68       121
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00